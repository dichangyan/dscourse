# %%
# !type data\demo.csv
# Out:
# id,name,age,gender,grade
# 1,Steven,20,Male,80
# 2,Elsa,18,Femail,100
# 3,John,15,Male,90

# %%
import pandas as pd

df = pd.read_csv('data/demo.csv')
df
# Out:
#    id    name  age  gender  grade
# 0   1  Steven   20    Male     80
# 1   2    Elsa   18  Femail    100
# 2   3    John   15    Male     90

# %%
df = pd.read_csv('data/demo.table', sep='\t')
df
# Out:
#                             id    name              age  gender  grade
# 0                            1  Steven         20  Male      80    NaN
# 1                            2    Elsa  18  Female  100     NaN    NaN
# 2                            3    John         15  Male      90    NaN
# 3                            4   Sally               20  Female  100.0
# 4                            5    Jack         28  Male      90    NaN
# 5  6   Rose    18  Female  100     NaN              NaN     NaN    NaN

# %%
df = pd.read_csv('data/demo.table', sep=' ')
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-c63c85dcb88e> in <module>
# ----> 1 df = pd.read_csv('data/demo.table', sep=' ')
#       2 df
#
# c:\users\administrator\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# c:\users\administrator\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# c:\users\administrator\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1194     def read(self, nrows=None):
#    1195         nrows = _validate_integer("nrows", nrows)
# -> 1196         ret = self._engine.read(nrows)
#    1197
#    1198         # May alter columns / col_dict
#
# c:\users\administrator\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2153     def read(self, nrows=None):
#    2154         try:
# -> 2155             data = self._reader.read(nrows)
#    2156         except StopIteration:
#    2157             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 3 fields in line 3, saw 5

# %%
df = pd.read_csv('data/demo.table', sep='\s+')
df
# Out:
#    id    name  age  gender  grade
# 0   1  Steven   20    Male     80
# 1   2    Elsa   18  Female    100
# 2   3    John   15    Male     90
# 3   4   Sally   20  Female    100
# 4   5    Jack   28    Male     90
# 5   6    Rose   18  Female    100

# %% [markdown]
# ### Missing data

# %%
from numpy import nan

df.iloc[2:4,2]=nan
df.iloc[2,3]=nan

df
# Out:
#    id    name   age  gender  grade
# 0   1  Steven  20.0    Male     80
# 1   2    Elsa  18.0  Female    100
# 2   3    John   NaN     NaN     90
# 3   4   Sally   NaN  Female    100
# 4   5    Jack  28.0    Male     90
# 5   6    Rose  18.0  Female    100

# %%
df.dropna()
# Out:
#    id    name   age  gender  grade
# 0   1  Steven  20.0    Male     80
# 1   2    Elsa  18.0  Female    100
# 4   5    Jack  28.0    Male     90
# 5   6    Rose  18.0  Female    100

# %%
df.fillna(0)
# Out:
#    id    name   age  gender  grade
# 0   1  Steven  20.0    Male     80
# 1   2    Elsa  18.0  Female    100
# 2   3    John   0.0       0     90
# 3   4   Sally   0.0  Female    100
# 4   5    Jack  28.0    Male     90
# 5   6    Rose  18.0  Female    100

# %%
df.fillna({'age':0,'gender':'Unknown'})
# Out:
#    id    name   age   gender  grade
# 0   1  Steven  20.0     Male     80
# 1   2    Elsa  18.0   Female    100
# 2   3    John   0.0  Unknown     90
# 3   4   Sally   0.0   Female    100
# 4   5    Jack  28.0     Male     90
# 5   6    Rose  18.0   Female    100

# %%
df.fillna(method='ffill', limit=1)
# Out:
#    id    name   age  gender  grade
# 0   1  Steven  20.0    Male     80
# 1   2    Elsa  18.0  Female    100
# 2   3    John  18.0  Female     90
# 3   4   Sally   NaN  Female    100
# 4   5    Jack  28.0    Male     90
# 5   6    Rose  18.0  Female    100

# %%
df.fillna(df.mean())
# Out:
#    id    name   age  gender  grade
# 0   1  Steven  20.0    Male     80
# 1   2    Elsa  18.0  Female    100
# 2   3    John  21.0     NaN     90
# 3   4   Sally  21.0  Female    100
# 4   5    Jack  28.0    Male     90
# 5   6    Rose  18.0  Female    100

# %% [markdown]
# ### Duplicated values

# %%
newitem = {'id':6,'name':'Rose', 'age':18.0, 'gender':'Female','grade':100}
df_dup = df.append(newitem, ignore_index=True)
df_dup
# Out:
#    id    name   age  gender  grade
# 0   1  Steven  20.0    Male     80
# 1   2    Elsa  18.0  Female    100
# 2   3    John   NaN     NaN     90
# 3   4   Sally   NaN  Female    100
# 4   5    Jack  28.0    Male     90
# 5   6    Rose  18.0  Female    100
# 6   6    Rose  18.0  Female    100

# %%
df_dup.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
df_dup.drop_duplicates()
# Out:
#    id    name   age  gender  grade
# 0   1  Steven  20.0    Male     80
# 1   2    Elsa  18.0  Female    100
# 2   3    John   NaN     NaN     90
# 3   4   Sally   NaN  Female    100
# 4   5    Jack  28.0    Male     90
# 5   6    Rose  18.0  Female    100

# %%
# specify a subset of column to drop the duplicated
df_dup.drop_duplicates(['age', 'gender'])
# Out:
#    id    name   age  gender  grade
# 0   1  Steven  20.0    Male     80
# 1   2    Elsa  18.0  Female    100
# 2   3    John   NaN     NaN     90
# 3   4   Sally   NaN  Female    100
# 4   5    Jack  28.0    Male     90

# %% [markdown]
# ### Data Transform

# %%
df.gender.apply(lambda x:1 if x == 'Female' else 0)
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# 5    1
# Name: gender, dtype: int64

# %%
df
# Out:
#    id    name   age  gender  grade
# 0   1  Steven  20.0    Male     80
# 1   2    Elsa  18.0  Female    100
# 2   3    John   NaN     NaN     90
# 3   4   Sally   NaN  Female    100
# 4   5    Jack  28.0    Male     90
# 5   6    Rose  18.0  Female    100

# %%
df['gender'] = df.gender.apply(lambda x:1 if x == 'Female' else 0)
df
# Out:
#    id    name   age  gender  grade
# 0   1  Steven  20.0       0     80
# 1   2    Elsa  18.0       1    100
# 2   3    John   NaN       0     90
# 3   4   Sally   NaN       1    100
# 4   5    Jack  28.0       0     90
# 5   6    Rose  18.0       1    100

# %%
df = pd.read_csv('data/demo.table', sep='\s+')

#map
grade_mapper = {
    100:'A+',
    90:'A',
    80:'B',
    70:'C'
}
df_graded = df.grade.map(grade_mapper)
df_graded
# Out:
# 0     B
# 1    A+
# 2     A
# 3    A+
# 4     A
# 5    A+
# Name: grade, dtype: object

# %%
df['grade']=df_graded
df
# Out:
#    id    name  age  gender grade
# 0   1  Steven   20    Male     B
# 1   2    Elsa   18  Female    A+
# 2   3    John   15    Male     A
# 3   4   Sally   20  Female    A+
# 4   5    Jack   28    Male     A
# 5   6    Rose   18  Female    A+

# %%
df.id.map(lambda x:x*10)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# Name: id, dtype: int64

# %%
df.grade.replace('A+', 'A')
# Out:
# 0    B
# 1    A
# 2    A
# 3    A
# 4    A
# 5    A
# Name: grade, dtype: object

# %%
df.age.replace([0,20], 20)
# Out:
# 0    20
# 1    18
# 2    15
# 3    20
# 4    28
# 5    18
# Name: age, dtype: int64

# %%
df.columns = df.columns.map(lambda x:x.upper())
# to modify index, use df.index.map
df
# Out:
#    ID    NAME  AGE  GENDER GRADE
# 0   1  Steven   20    Male     B
# 1   2    Elsa   18  Female    A+
# 2   3    John   15    Male     A
# 3   4   Sally   20  Female    A+
# 4   5    Jack   28    Male     A
# 5   6    Rose   18  Female    A+

# %%
df
# Out:
#    ID    NAME  AGE  GENDER GRADE
# 0   1  Steven   20    Male     B
# 1   2    Elsa   18  Female    A+
# 2   3    John   15    Male     A
# 3   4   Sally   20  Female    A+
# 4   5    Jack   28    Male     A
# 5   6    Rose   18  Female    A+

# %%
df.rename(index={5:55555},columns={'GRADE':'GRA'})
# Out:
#        ID    NAME  AGE  GENDER GRA
# 0       1  Steven   20    Male   B
# 1       2    Elsa   18  Female  A+
# 2       3    John   15    Male   A
# 3       4   Sally   20  Female  A+
# 4       5    Jack   28    Male   A
# 55555   6    Rose   18  Female  A+

# %% [markdown]
# ### Discretization and Binning

# %%
import json
df = pd.read_json('data/acc-demo1.json')
df
# Out:
#             x       y       z
# 0      0.0560 -0.6716 -0.7525
# 1      0.0778 -0.6766 -0.7276
# 2      0.0673 -0.6601 -0.7863
# 3      0.0464 -0.6532 -0.7278
# 4      0.0354 -0.6551 -0.7671
# ...       ...     ...     ...
# 17890  0.0333 -0.7142 -0.6958
# 17891  0.0472 -0.7123 -0.6898
# 17892  0.0469 -0.7097 -0.6989
# 17893  0.0397 -0.7109 -0.6955
# 17894  0.0005 -0.7260 -0.7240
#
# [17895 rows x 3 columns]

# %%
bins = [-3,-1,-0.5, 0, 0.5, 1,3]
interval = pd.cut(df.z, bins)
interval
# Out:
# 0        (-1.0, -0.5]
# 1        (-1.0, -0.5]
# 2        (-1.0, -0.5]
# 3        (-1.0, -0.5]
# 4        (-1.0, -0.5]
#              ...
# 17890    (-1.0, -0.5]
# 17891    (-1.0, -0.5]
# 17892    (-1.0, -0.5]
# 17893    (-1.0, -0.5]
# 17894    (-1.0, -0.5]
# Name: z, Length: 17895, dtype: category
# Categories (6, interval[float64]): [(-3.0, -1.0] < (-1.0, -0.5] < (-0.5, 0.0] < (0.0, 0.5] < (0.5, 1.0] < (1.0, 3.0]]

# %%
pd.value_counts(interval)
# Out:
# (-1.0, -0.5]    17762
# (-3.0, -1.0]      103
# (-0.5, 0.0]        30
# (1.0, 3.0]          0
# (0.5, 1.0]          0
# (0.0, 0.5]          0
# Name: z, dtype: int64

# %%
# pass an integer nunber of bins to cut instead of explicit bin edges
# it will compute equal-length bins based on the minimum and maximum values in the data
interval = pd.cut(df.z, 10, precision=2)
interval
# Out:
# 0        (-0.83, -0.73]
# 1        (-0.83, -0.73]
# 2        (-0.83, -0.73]
# 3        (-0.83, -0.73]
# 4        (-0.83, -0.73]
#               ...
# 17890    (-0.73, -0.63]
# 17891    (-0.73, -0.63]
# 17892    (-0.73, -0.63]
# 17893    (-0.73, -0.63]
# 17894    (-0.73, -0.63]
# Name: z, Length: 17895, dtype: category
# Categories (10, interval[float64]): [(-1.33, -1.23] < (-1.23, -1.13] < (-1.13, -1.03] < (-1.03, -0.93] ... (-0.73, -0.63] < (-0.63, -0.53] < (-0.53, -0.43] < (-0.43, -0.32]]

# %%
pd.value_counts(interval)
# Out:
# (-0.83, -0.73]    11097
# (-0.73, -0.63]     3837
# (-1.03, -0.93]     2142
# (-0.93, -0.83]      453
# (-0.63, -0.53]      269
# (-1.13, -1.03]       41
# (-0.53, -0.43]       34
# (-0.43, -0.32]       10
# (-1.23, -1.13]        7
# (-1.33, -1.23]        5
# Name: z, dtype: int64

# %%
# cut with quanties
interval = pd.qcut(df.z, 4)
pd.value_counts(interval)
# Out:
# (-1.3319999999999999, -0.773]    4524
# (-0.756, -0.729]                 4502
# (-0.729, -0.325]                 4439
# (-0.773, -0.756]                 4430
# Name: z, dtype: int64

# %% [markdown]
# ### Sampling

# %%
df.sample(n=10)
# Out:
#             x       y       z
# 16931  0.0371 -0.7073 -0.7053
# 12629 -0.1828 -0.3046 -0.9079
# 4867  -0.1091 -0.6359 -0.7331
# 11492 -0.0559 -0.1822 -0.9680
# 11646 -0.0416 -0.2090 -0.9579
# 6797  -0.1122 -0.6506 -0.7293
# 988    0.0220 -0.6482 -0.7463
# 16657  0.0318 -0.6812 -0.7214
# 12506 -0.0277 -0.2076 -0.9661
# 3436   0.0294 -0.6417 -0.7578

# %% [markdown]
# ### Permutation

# %%
import numpy as np

neworder = np.random.permutation(len(df))
neworder
# Out:
# array([ 7633, 13515,  4237, ..., 10479, 11272,  3951])

# %%
df.take(neworder)
# Out:
#             x       y       z
# 7633  -0.1203 -0.6561 -0.7233
# 13515 -0.0327 -0.6245 -0.7762
# 4237   0.0029 -0.6371 -0.7544
# 3817   0.0132 -0.6292 -0.7736
# 13097 -0.0394 -0.6122 -0.7757
# ...       ...     ...     ...
# 17740  0.0385 -0.7138 -0.6922
# 11047 -0.0643 -0.1829 -0.9632
# 10479  0.2095 -0.2648 -0.9436
# 11272 -0.0562 -0.1925 -0.9574
# 3951   0.0022 -0.6357 -0.7697
#
# [17895 rows x 3 columns]

# %% [markdown]
# ### Outliers

# %%
import json
df = pd.read_json('data/acc-demo1.json')
df
# Out:
#             x       y       z
# 0      0.0560 -0.6716 -0.7525
# 1      0.0778 -0.6766 -0.7276
# 2      0.0673 -0.6601 -0.7863
# 3      0.0464 -0.6532 -0.7278
# 4      0.0354 -0.6551 -0.7671
# ...       ...     ...     ...
# 17890  0.0333 -0.7142 -0.6958
# 17891  0.0472 -0.7123 -0.6898
# 17892  0.0469 -0.7097 -0.6989
# 17893  0.0397 -0.7109 -0.6955
# 17894  0.0005 -0.7260 -0.7240
#
# [17895 rows x 3 columns]

# %%
df.describe()
# Out:
#                   x             y             z
# count  17895.000000  17895.000000  17895.000000
# mean      -0.037648     -0.593152     -0.771278
# std        0.073596      0.157430      0.085195
# min       -0.521900     -0.904100     -1.330700
# 25%       -0.099300     -0.658200     -0.773100
# 50%       -0.031500     -0.642400     -0.755800
# 75%        0.016800     -0.624900     -0.729300
# max        0.605300     -0.060600     -0.324900

# %%
import numpy as np

df.z[np.abs(df.z)>1]
# Out:
# 4620    -1.0010
# 4625    -1.0688
# 5046    -1.0214
# 5834    -1.0051
# 5874    -1.0163
#           ...
# 12918   -1.0582
# 12988   -1.2594
# 12989   -1.1464
# 15237   -1.2280
# 15279   -1.0422
# Name: z, Length: 103, dtype: float64

# %%
df[(np.abs(df)>0.7).any(axis=1)]
# Out:
#             x       y       z
# 0      0.0560 -0.6716 -0.7525
# 1      0.0778 -0.6766 -0.7276
# 2      0.0673 -0.6601 -0.7863
# 3      0.0464 -0.6532 -0.7278
# 4      0.0354 -0.6551 -0.7671
# ...       ...     ...     ...
# 17890  0.0333 -0.7142 -0.6958
# 17891  0.0472 -0.7123 -0.6898
# 17892  0.0469 -0.7097 -0.6989
# 17893  0.0397 -0.7109 -0.6955
# 17894  0.0005 -0.7260 -0.7240
#
# [17555 rows x 3 columns]

# %%
np.abs(df)>0.7
# Out:
#            x      y      z
# 0      False  False   True
# 1      False  False   True
# 2      False  False   True
# 3      False  False   True
# 4      False  False   True
# ...      ...    ...    ...
# 17890  False   True  False
# 17891  False   True  False
# 17892  False   True  False
# 17893  False   True  False
# 17894  False   True   True
#
# [17895 rows x 3 columns]

# %%
(np.abs(df)>0.7).any(0)
# Out:
# x    False
# y     True
# z     True
# dtype: bool

# %%
(np.abs(df)>0.7).any(1)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 17890    True
# 17891    True
# 17892    True
# 17893    True
# 17894    True
# Length: 17895, dtype: bool

# %%
df<df.quantile(0.75)
# Out:
#            x     y      z
# 0      False  True   True
# 1      False  True  False
# 2      False  True   True
# 3      False  True  False
# 4      False  True   True
# ...      ...   ...    ...
# 17890  False  True  False
# 17891  False  True  False
# 17892  False  True  False
# 17893  False  True  False
# 17894   True  True  False
#
# [17895 rows x 3 columns]

# %%
df.std()
# Out:
# x    0.073596
# y    0.157430
# z    0.085195
# dtype: float64

# %%
df.mean()
# Out:
# x   -0.037648
# y   -0.593152
# z   -0.771278
# dtype: float64
